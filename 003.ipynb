# %%
my_dict = {
    "name": "Raghav",
    "age": 23,
    "city": "Bijapur"
}

# %%
my_dict
# Out:
# {'name': 'Raghav', 'age': 23, 'city': 'Bijapur'}

# %%
opt_1="walk"
opt_2="take a cab"
opt_3="travel via train"
opt_4="take a flight"

# %%
dist = 48

# %%
if dist<10:
    print(f"chosen option: {opt_1}")
else:
    print(f"chosen option: {opt_2}")
# Out:
# chosen option: take a cab

# %%
if 60:
    print(f"chosen option: {opt_3}")
else:
    print(f"chosen option: {opt_4}")
# Out:
# chosen option: travel via train

# %%
user_name = input("Please enter your name")

print(f"Hello (user_name! Welcome to Python Cafe")

food_choice = input("Please type V [Veg and N[Non Veg]")

add_spices = input("Please type Y to add spices and N to not add spices  ")


menu ={
    "option1": ["coffee", "V", "N"],
    "option2": ["Ramen", "V", "Y"],
    "option3": ["Pasta", "N", "Y"],
    "option4": ["Briyani","N","Y"],
    "option5": ["sandwich","V","N"],
    "option6": ["pizza","N","Y"]
}

for key, value in menu.items():
    #check wheather menu item is veg or non veg
    if value[1] == food_choice and value[2] == add_spices:
        print(value)
# Out:
# Please enter your namerag
# Hello (user_name! Welcome to Python Cafe
# Please type V [Veg and N[Non Veg]n
# Please type Y to add spices and N to not add spices  y
